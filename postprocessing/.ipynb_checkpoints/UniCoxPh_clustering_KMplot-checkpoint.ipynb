# %% [markdown]
# # In this notebook, the following things are done for BRCA
# * [Univarite CoxPH model for seleting significant features](#CoxPH)
# * [Clustering for generating the gorups](#Clustering(Using-k-means-clustering-and-plot-it-based-PCA-features))
# * [KM Plot generation and calculate logrank p-value](#KM-Plot-Generation-for-each-cluster-using-KaplanMeier-Filter)

# %%
import os
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score

# %%
from lifelines import CoxPHFitter 
import xenaPython as xena
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test, multivariate_logrank_test
# Out:
# /home/pdutta/anaconda3/envs/dgcca/lib/python3.7/site-packages/xenaPython/__init__.py:110: FutureWarning: Possible nested set at position 7
#   re.sub(r"^[^[]+[[]([^]]*)[]].*$", r"\1", query, flags=re.DOTALL))

# %%
from chart_studio import plotly
import plotly.graph_objs as go
from plotly import tools
import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sb

# %%
PARAM_DETAILS_PATH = "/home/pdutta/Github/Multiview_clustering_DGCCA/results/final_embedding/BRCA/parameters_details.npy"
read_dictionary = np.load(PARAM_DETAILS_PATH,allow_pickle='TRUE').item()
# print(read_dictionary['hello']) # displays "world"
CANCER = read_dictionary['cancer_type']
DATA_PATH = "/home/pdutta/Data/DGCCA/"
RESULT_PATH= "/home/pdutta/Github/Multiview_clustering_DGCCA/results/"
UNI_COX_MODEL_PATH = RESULT_PATH + 'UniCoX_embedding/{}/'.format(CANCER)

# %%
read_dictionary['csv_path']
# Out:
# '/home/pdutta/Github/Multiview_clustering_DGCCA/results/final_embedding/BRCA/final_embedding_embed_views=3_numEpochs=20__val_batch_size=32__train_batch_size=32__arch=[[1000,500],[900,400],[200,150]]__lr=0.001__latDim=100.csv'

# %%
if not os.path.exists(UNI_COX_MODEL_PATH):
    os.makedirs(UNI_COX_MODEL_PATH)

# %%
id_mapping = pd.read_csv('/home/pdutta/Data/DGCCA/TCGA_{}/methyl_rnaseq_mirna_minmax_idmapping.tsv'.format(CANCER), sep='\t')

# %% [markdown]
# ### Get the final embedding which is obtained from DGCCA

# %%
df_embedding = pd.read_csv(read_dictionary['csv_path'])
df_embedding.index = id_mapping['sample']

# %%
df_embedding
# Out:
#                   DGCCA_1   DGCCA_2   DGCCA_3   DGCCA_4   DGCCA_5   DGCCA_6  \
# sample
# TCGA-3C-AAAU-01 -0.031982 -0.025014 -0.008117 -0.058464 -0.040356 -0.028346
# TCGA-3C-AALI-01 -0.029415  0.014362  0.002028 -0.032183 -0.011660  0.012012
# TCGA-3C-AALJ-01  0.079286 -0.015032 -0.003936  0.046055 -0.003243  0.036024
# TCGA-3C-AALK-01 -0.006042  0.031674  0.011650  0.043692  0.038184  0.026063
# TCGA-4H-AAAK-01 -0.069437  0.003531  0.007110 -0.056672 -0.056163 -0.035640
# ...                   ...       ...       ...       ...       ...       ...
# TCGA-WT-AB44-01 -0.040014 -0.033172 -0.028909 -0.050056 -0.062379 -0.013123
# TCGA-XX-A899-01 -0.103177  0.068520  0.067054 -0.059398  0.075429 -0.119528
# TCGA-XX-A89A-01 -0.040290 -0.018530 -0.023485  0.064159 -0.046308 -0.069077
# TCGA-Z7-A8R5-01 -0.012388  0.060089 -0.023507  0.008006  0.029531 -0.009154
# TCGA-Z7-A8R6-01 -0.016012  0.001234 -0.044691  0.118741  0.068427  0.064792
#
#                   DGCCA_7   DGCCA_8   DGCCA_9  DGCCA_10  ...  DGCCA_91  \
# sample                                                   ...
# TCGA-3C-AAAU-01  0.051894 -0.017878 -0.014760 -0.005154  ... -0.033919
# TCGA-3C-AALI-01  0.022462 -0.000358 -0.017936  0.013668  ... -0.043551
# TCGA-3C-AALJ-01 -0.051727  0.018718  0.028734  0.022740  ...  0.040729
# TCGA-3C-AALK-01 -0.045367  0.031156 -0.004619  0.035518  ...  0.013721
# TCGA-4H-AAAK-01  0.067334  0.023515 -0.065170  0.011650  ... -0.076885
# ...                   ...       ...       ...       ...  ...       ...
# TCGA-WT-AB44-01  0.064285  0.108157 -0.001992 -0.048317  ...  0.079249
# TCGA-XX-A899-01 -0.024508 -0.034113  0.054565 -0.063097  ...  0.030427
# TCGA-XX-A89A-01 -0.020624 -0.055273  0.040186  0.027586  ... -0.012752
# TCGA-Z7-A8R5-01  0.050544  0.050777 -0.046752  0.013256  ... -0.125952
# TCGA-Z7-A8R6-01  0.040153 -0.017383 -0.065701 -0.092226  ...  0.003120
#
#                  DGCCA_92  DGCCA_93  DGCCA_94  DGCCA_95  DGCCA_96  DGCCA_97  \
# sample
# TCGA-3C-AAAU-01 -0.026588  0.007012 -0.039131  0.013876 -0.030776 -0.039958
# TCGA-3C-AALI-01 -0.031762 -0.005569 -0.016724 -0.034798 -0.010267 -0.027901
# TCGA-3C-AALJ-01  0.059767 -0.000575 -0.006727  0.055739 -0.010193 -0.000019
# TCGA-3C-AALK-01 -0.043100  0.030484  0.039396  0.058761  0.035527  0.032345
# TCGA-4H-AAAK-01 -0.071633  0.009872  0.045033 -0.061238  0.033515  0.034351
# ...                   ...       ...       ...       ...       ...       ...
# TCGA-WT-AB44-01  0.012036 -0.062293 -0.037285 -0.064171 -0.026579  0.079333
# TCGA-XX-A899-01  0.025327  0.023870 -0.069730 -0.015511 -0.008294  0.030220
# TCGA-XX-A89A-01 -0.111431 -0.058677  0.000439 -0.029079 -0.016945 -0.040031
# TCGA-Z7-A8R5-01  0.024498  0.019308  0.002543 -0.048318  0.051835 -0.130495
# TCGA-Z7-A8R6-01  0.030747 -0.046692  0.106589  0.087180 -0.035830  0.002864
#
#                  DGCCA_98  DGCCA_99  DGCCA_100
# sample
# TCGA-3C-AAAU-01 -0.031732 -0.022244  -0.026451
# TCGA-3C-AALI-01 -0.012578 -0.022498   0.003283
# TCGA-3C-AALJ-01 -0.005444 -0.018707  -0.043705
# TCGA-3C-AALK-01  0.025681 -0.024414   0.044123
# TCGA-4H-AAAK-01  0.049669  0.047660   0.050691
# ...                   ...       ...        ...
# TCGA-WT-AB44-01 -0.035998  0.028637  -0.065067
# TCGA-XX-A899-01  0.009073 -0.077709  -0.035043
# TCGA-XX-A89A-01  0.071704 -0.043364   0.036465
# TCGA-Z7-A8R5-01 -0.009894  0.070522   0.038007
# TCGA-Z7-A8R6-01  0.112322 -0.016485  -0.052588
#
# [1233 rows x 100 columns]

# %% [markdown]
# ### Get the survival file and generate the dataframe

# %%
host = xena.PUBLIC_HUBS['tcgaHub']
dataset = 'survival/{}_survival.txt'.format(CANCER)

# %%
samples = xena.dataset_samples (host, dataset, None)
features = xena.dataset_field(host, dataset)
features
# Out:
# ['DFI',
#  'DFI.time',
#  'DSS',
#  'DSS.time',
#  'OS',
#  'OS.time',
#  'PFI',
#  'PFI.time',
#  'Redaction',
#  '_PATIENT',
#  'sampleID']

# %%
[position, [status,time]] = xena.dataset_probe_values(host, dataset, samples, ['OS','OS.time'])
df_status = pd.DataFrame(list(zip(samples, time, status)), columns = ['sample','time', 'status'])
df_status = df_status.set_index('sample')
df_status.to_csv("clinical.csv")

# %%
df_status
# Out:
#                  time  status
# sample
# TCGA-3C-AAAU-01  4047       0
# TCGA-3C-AALI-01  4005       0
# TCGA-3C-AALJ-01  1474       0
# TCGA-3C-AALK-01  1448       0
# TCGA-4H-AAAK-01   348       0
# ...               ...     ...
# TCGA-WT-AB44-01   883       0
# TCGA-XX-A899-01   467       0
# TCGA-XX-A89A-01   488       0
# TCGA-Z7-A8R5-01  3287       0
# TCGA-Z7-A8R6-01  3256       0
#
# [1236 rows x 2 columns]

# %%
print(df_status.shape, df_embedding.shape)
df_merge = pd.merge(df_embedding, df_status, on='sample')
print(df_merge.head())
print(df_merge.shape)
print(df_merge.groupby(['status']).size())
# Out:
# (1236, 2) (1233, 100)
#                   DGCCA_1   DGCCA_2   DGCCA_3   DGCCA_4   DGCCA_5   DGCCA_6  \
# sample
# TCGA-3C-AAAU-01 -0.031982 -0.025014 -0.008117 -0.058464 -0.040356 -0.028346
# TCGA-3C-AALI-01 -0.029415  0.014362  0.002028 -0.032183 -0.011660  0.012012
# TCGA-3C-AALJ-01  0.079286 -0.015032 -0.003936  0.046055 -0.003243  0.036024
# TCGA-3C-AALK-01 -0.006042  0.031674  0.011650  0.043692  0.038184  0.026063
# TCGA-4H-AAAK-01 -0.069437  0.003531  0.007110 -0.056672 -0.056163 -0.035640
#
#                   DGCCA_7   DGCCA_8   DGCCA_9  DGCCA_10  ...  DGCCA_93  \
# sample                                                   ...
# TCGA-3C-AAAU-01  0.051894 -0.017878 -0.014760 -0.005154  ...  0.007012
# TCGA-3C-AALI-01  0.022462 -0.000358 -0.017936  0.013668  ... -0.005569
# TCGA-3C-AALJ-01 -0.051727  0.018718  0.028734  0.022740  ... -0.000575
# TCGA-3C-AALK-01 -0.045367  0.031156 -0.004619  0.035518  ...  0.030484
# TCGA-4H-AAAK-01  0.067334  0.023515 -0.065170  0.011650  ...  0.009872
#
#                  DGCCA_94  DGCCA_95  DGCCA_96  DGCCA_97  DGCCA_98  DGCCA_99  \
# sample
# TCGA-3C-AAAU-01 -0.039131  0.013876 -0.030776 -0.039958 -0.031732 -0.022244
# TCGA-3C-AALI-01 -0.016724 -0.034798 -0.010267 -0.027901 -0.012578 -0.022498
# TCGA-3C-AALJ-01 -0.006727  0.055739 -0.010193 -0.000019 -0.005444 -0.018707
# TCGA-3C-AALK-01  0.039396  0.058761  0.035527  0.032345  0.025681 -0.024414
# TCGA-4H-AAAK-01  0.045033 -0.061238  0.033515  0.034351  0.049669  0.047660
#
#                  DGCCA_100  time  status
# sample
# TCGA-3C-AAAU-01  -0.026451  4047       0
# TCGA-3C-AALI-01   0.003283  4005       0
# TCGA-3C-AALJ-01  -0.043705  1474       0
# TCGA-3C-AALK-01   0.044123  1448       0
# TCGA-4H-AAAK-01   0.050691   348       0
#
# [5 rows x 102 columns]
# (1230, 102)
# status
# 0    1028
# 1     202
# dtype: int64

# %%
print(set(df_status.index.values).difference(set(df_embedding.index.values)))
print(set(df_embedding.index.values).difference(set(df_status.index.values)))
print(set(df_embedding.index.values) ^ (set(df_status.index.values)))
# Out:
# {'TCGA-BH-A0BO-11', 'TCGA-E2-A14Y-11', 'TCGA-E2-A15L-11', 'TCGA-BH-A18F-11', 'TCGA-BH-A0BL-11', 'TCGA-BH-A0DE-11'}
# {'TCGA-E2-A1IP-01', 'TCGA-BH-A0B2-01', 'TCGA-BH-A0B2-11'}
# {'TCGA-BH-A18F-11', 'TCGA-E2-A1IP-01', 'TCGA-BH-A0B2-01', 'TCGA-BH-A0BL-11', 'TCGA-BH-A0B2-11', 'TCGA-BH-A0BO-11', 'TCGA-E2-A15L-11', 'TCGA-BH-A0DE-11', 'TCGA-E2-A14Y-11'}

# %% [markdown]
# <a id='CoxPH'></a>
# ### Univariate CoxPH model

# %%
df_merge = df_merge.replace('NaN', np.nan)
df_merge = df_merge.dropna()
df_merge
# Out:
#                   DGCCA_1   DGCCA_2   DGCCA_3   DGCCA_4   DGCCA_5   DGCCA_6  \
# sample
# TCGA-3C-AAAU-01 -0.031982 -0.025014 -0.008117 -0.058464 -0.040356 -0.028346
# TCGA-3C-AALI-01 -0.029415  0.014362  0.002028 -0.032183 -0.011660  0.012012
# TCGA-3C-AALJ-01  0.079286 -0.015032 -0.003936  0.046055 -0.003243  0.036024
# TCGA-3C-AALK-01 -0.006042  0.031674  0.011650  0.043692  0.038184  0.026063
# TCGA-4H-AAAK-01 -0.069437  0.003531  0.007110 -0.056672 -0.056163 -0.035640
# ...                   ...       ...       ...       ...       ...       ...
# TCGA-WT-AB44-01 -0.040014 -0.033172 -0.028909 -0.050056 -0.062379 -0.013123
# TCGA-XX-A899-01 -0.103177  0.068520  0.067054 -0.059398  0.075429 -0.119528
# TCGA-XX-A89A-01 -0.040290 -0.018530 -0.023485  0.064159 -0.046308 -0.069077
# TCGA-Z7-A8R5-01 -0.012388  0.060089 -0.023507  0.008006  0.029531 -0.009154
# TCGA-Z7-A8R6-01 -0.016012  0.001234 -0.044691  0.118741  0.068427  0.064792
#
#                   DGCCA_7   DGCCA_8   DGCCA_9  DGCCA_10  ...  DGCCA_93  \
# sample                                                   ...
# TCGA-3C-AAAU-01  0.051894 -0.017878 -0.014760 -0.005154  ...  0.007012
# TCGA-3C-AALI-01  0.022462 -0.000358 -0.017936  0.013668  ... -0.005569
# TCGA-3C-AALJ-01 -0.051727  0.018718  0.028734  0.022740  ... -0.000575
# TCGA-3C-AALK-01 -0.045367  0.031156 -0.004619  0.035518  ...  0.030484
# TCGA-4H-AAAK-01  0.067334  0.023515 -0.065170  0.011650  ...  0.009872
# ...                   ...       ...       ...       ...  ...       ...
# TCGA-WT-AB44-01  0.064285  0.108157 -0.001992 -0.048317  ... -0.062293
# TCGA-XX-A899-01 -0.024508 -0.034113  0.054565 -0.063097  ...  0.023870
# TCGA-XX-A89A-01 -0.020624 -0.055273  0.040186  0.027586  ... -0.058677
# TCGA-Z7-A8R5-01  0.050544  0.050777 -0.046752  0.013256  ...  0.019308
# TCGA-Z7-A8R6-01  0.040153 -0.017383 -0.065701 -0.092226  ... -0.046692
#
#                  DGCCA_94  DGCCA_95  DGCCA_96  DGCCA_97  DGCCA_98  DGCCA_99  \
# sample
# TCGA-3C-AAAU-01 -0.039131  0.013876 -0.030776 -0.039958 -0.031732 -0.022244
# TCGA-3C-AALI-01 -0.016724 -0.034798 -0.010267 -0.027901 -0.012578 -0.022498
# TCGA-3C-AALJ-01 -0.006727  0.055739 -0.010193 -0.000019 -0.005444 -0.018707
# TCGA-3C-AALK-01  0.039396  0.058761  0.035527  0.032345  0.025681 -0.024414
# TCGA-4H-AAAK-01  0.045033 -0.061238  0.033515  0.034351  0.049669  0.047660
# ...                   ...       ...       ...       ...       ...       ...
# TCGA-WT-AB44-01 -0.037285 -0.064171 -0.026579  0.079333 -0.035998  0.028637
# TCGA-XX-A899-01 -0.069730 -0.015511 -0.008294  0.030220  0.009073 -0.077709
# TCGA-XX-A89A-01  0.000439 -0.029079 -0.016945 -0.040031  0.071704 -0.043364
# TCGA-Z7-A8R5-01  0.002543 -0.048318  0.051835 -0.130495 -0.009894  0.070522
# TCGA-Z7-A8R6-01  0.106589  0.087180 -0.035830  0.002864  0.112322 -0.016485
#
#                  DGCCA_100    time  status
# sample
# TCGA-3C-AAAU-01  -0.026451  4047.0       0
# TCGA-3C-AALI-01   0.003283  4005.0       0
# TCGA-3C-AALJ-01  -0.043705  1474.0       0
# TCGA-3C-AALK-01   0.044123  1448.0       0
# TCGA-4H-AAAK-01   0.050691   348.0       0
# ...                    ...     ...     ...
# TCGA-WT-AB44-01  -0.065067   883.0       0
# TCGA-XX-A899-01  -0.035043   467.0       0
# TCGA-XX-A89A-01   0.036465   488.0       0
# TCGA-Z7-A8R5-01   0.038007  3287.0       0
# TCGA-Z7-A8R6-01  -0.052588  3256.0       0
#
# [1229 rows x 102 columns]

# %%
df_uni_cox_result= pd.DataFrame(columns=['feature_name', 'coefficient', 'coef_lower_95%','coef_upper_95%','z-value','p-value','-log2(p)','partial_AIC','C-index'])
temp = 0
for i in df_merge.columns[:-2]:
    data_r= df_merge.loc[:,[i,'time', 'status']]
    cph = CoxPHFitter()   
    cph.fit(data_r, 'time', event_col='status') 
    df_uni_cox_result.loc[temp, ['feature_name']] = i
    df_uni_cox_result.loc[temp, ['coefficient']] = cph.summary.loc[i]['coef']
    df_uni_cox_result.loc[temp, ['coef_lower_95%']] = cph.summary.loc[i]['coef lower 95%']
    df_uni_cox_result.loc[temp, ['coef_upper_95%']] = cph.summary.loc[i]['coef upper 95%']
    df_uni_cox_result.loc[temp, ['z-value']] = cph.summary.loc[i]['z']
    df_uni_cox_result.loc[temp, ['p-value']] = cph.summary.loc[i]['p']
    df_uni_cox_result.loc[temp, ['-log2(p)']] = cph.summary.loc[i]['-log2(p)']
    df_uni_cox_result.loc[temp, ['partial_AIC']] = cph.AIC_partial_
    df_uni_cox_result.loc[temp, ['C-index']] = cph.concordance_index_
    temp=temp +1

# %%
df_uni_cox_result
# Out:
#    feature_name coefficient coef_lower_95% coef_upper_95%   z-value   p-value  \
# 0       DGCCA_1   -0.601679      -4.469978       3.266619 -0.304855  0.760477
# 1       DGCCA_2   -2.246376      -6.105924       1.613172  -1.14076   0.25397
# 2       DGCCA_3    0.224586      -3.479551       3.928723  0.118835  0.905406
# 3       DGCCA_4   -0.510201      -3.692844       2.672442 -0.314197  0.753372
# 4       DGCCA_5    1.532145      -2.165502       5.229792  0.812124   0.41672
# ..          ...         ...            ...            ...       ...       ...
# 95     DGCCA_96    0.665519      -3.008268       4.339307  0.355054  0.722549
# 96     DGCCA_97    0.299783      -3.287994       3.887559  0.163768  0.869914
# 97     DGCCA_98    1.132108      -2.587688       4.851905  0.596509  0.550835
# 98     DGCCA_99   -2.398995      -6.018519        1.22053  -1.29905  0.193927
# 99    DGCCA_100   -3.425217      -7.366791       0.516357 -1.703203   0.08853
#
#     -log2(p)  partial_AIC   C-index
# 0   0.395024  2336.778483  0.520702
# 1    1.97727  2335.582586     0.555
# 2   0.143363  2336.857463  0.485076
# 3   0.408566  2336.772819   0.47602
# 4   1.262849   2336.21338  0.530713
# ..       ...          ...       ...
# 95  0.468833  2336.745573  0.522092
# 96  0.201056  2336.844747  0.477389
# 97  0.860307  2336.514446  0.515743
# 98  2.366416  2335.171865  0.528203
# 99  3.497689  2333.971777  0.557033
#
# [100 rows x 9 columns]

# %%
df_uni_cox_result.to_csv(UNI_COX_MODEL_PATH+"UniVaR_CoXPh_result.csv", index=False)

# %%
df_sig_feature = df_uni_cox_result.loc[(df_uni_cox_result['p-value'] < 0.05)].reset_index(drop=True)
df_sig_feature
# Out:
#   feature_name coefficient coef_lower_95% coef_upper_95%   z-value   p-value  \
# 0     DGCCA_12    3.583718       0.072489       7.094946  2.000427  0.045454
# 1     DGCCA_48    3.961697       0.287195         7.6362  2.113152  0.034588
# 2     DGCCA_65    4.453175       0.740455       8.165896  2.350854   0.01873
# 3     DGCCA_80    3.558887       0.059223        7.05855  1.993132  0.046247
#
#    -log2(p)  partial_AIC   C-index
# 0  4.459445  2332.897566  0.548028
# 1  4.853596  2332.524357  0.537747
# 2  5.738475  2331.420039   0.55058
# 3  4.434495  2332.910506  0.555052

# %%
important_features = list(df_sig_feature['feature_name'])
all_column_values = important_features + ['time','status']
df_survival = df_merge[all_column_values]
df_clustering = df_merge[important_features]

# %%
df_survival
# Out:
#                  DGCCA_12  DGCCA_48  DGCCA_65  DGCCA_80    time  status
# sample
# TCGA-3C-AAAU-01 -0.036247  0.027379 -0.015438  0.033716  4047.0       0
# TCGA-3C-AALI-01 -0.014227  0.066123 -0.054240 -0.019644  4005.0       0
# TCGA-3C-AALJ-01  0.020269 -0.028566  0.031784  0.009290  1474.0       0
# TCGA-3C-AALK-01 -0.019704  0.019438 -0.028259  0.002753  1448.0       0
# TCGA-4H-AAAK-01 -0.039866  0.051198 -0.021220 -0.026774   348.0       0
# ...                   ...       ...       ...       ...     ...     ...
# TCGA-WT-AB44-01  0.031216 -0.077855 -0.066040 -0.103475   883.0       0
# TCGA-XX-A899-01  0.043574 -0.001265  0.069903 -0.092965   467.0       0
# TCGA-XX-A89A-01 -0.021217 -0.056708  0.004293 -0.080839   488.0       0
# TCGA-Z7-A8R5-01  0.110441 -0.013585  0.106088 -0.035813  3287.0       0
# TCGA-Z7-A8R6-01 -0.031392 -0.015380 -0.083493  0.042941  3256.0       0
#
# [1229 rows x 6 columns]

# %%
df_clustering.to_csv(UNI_COX_MODEL_PATH+"UniVaR_cluster_feature.csv")

# %%
df_survival.to_csv(UNI_COX_MODEL_PATH+"UniVaR_survival_feature.csv")

# %% [markdown]
# ## Clustering(Using k-means clustering and plot it based PCA features)

# %%
pca = PCA(n_components=2)
embedding_pca = pca.fit_transform(df_clustering)
#print(embedding_pca)
df_clustering['PCA_1'] = embedding_pca[:,0]
df_clustering['PCA_2'] = embedding_pca[:,1]
df_clustering
# Out:
#                  DGCCA_12  DGCCA_48  DGCCA_65  DGCCA_80     PCA_1     PCA_2
# sample
# TCGA-3C-AAAU-01 -0.036247  0.027379 -0.015438  0.033716 -0.030499  0.024282
# TCGA-3C-AALI-01 -0.014227  0.066123 -0.054240 -0.019644 -0.024807  0.049445
# TCGA-3C-AALJ-01  0.020269 -0.028566  0.031784  0.009290  0.015495 -0.037307
# TCGA-3C-AALK-01 -0.019704  0.019438 -0.028259  0.002753 -0.020256  0.028869
# TCGA-4H-AAAK-01 -0.039866  0.051198 -0.021220 -0.026774  0.006610  0.055602
# ...                   ...       ...       ...       ...       ...       ...
# TCGA-WT-AB44-01  0.031216 -0.077855 -0.066040 -0.103475  0.020551  0.040528
# TCGA-XX-A899-01  0.043574 -0.001265  0.069903 -0.092965  0.110309 -0.031090
# TCGA-XX-A89A-01 -0.021217 -0.056708  0.004293 -0.080839  0.061071  0.041382
# TCGA-Z7-A8R5-01  0.110441 -0.013585  0.106088 -0.035813  0.091406 -0.124139
# TCGA-Z7-A8R6-01 -0.031392 -0.015380 -0.083493  0.042941 -0.086312  0.045404
#
# [1229 rows x 6 columns]

# %%
df_clustering.iloc[:,-2]
# Out:
# sample
# TCGA-3C-AAAU-01   -0.030499
# TCGA-3C-AALI-01   -0.024807
# TCGA-3C-AALJ-01    0.015495
# TCGA-3C-AALK-01   -0.020256
# TCGA-4H-AAAK-01    0.006610
#                      ...
# TCGA-WT-AB44-01    0.020551
# TCGA-XX-A899-01    0.110309
# TCGA-XX-A89A-01    0.061071
# TCGA-Z7-A8R5-01    0.091406
# TCGA-Z7-A8R6-01   -0.086312
# Name: PCA_1, Length: 1229, dtype: float64

# %%
clustering_data = df_clustering.iloc[:,:-2]
clustering_data
# Out:
#                  DGCCA_12  DGCCA_48  DGCCA_65  DGCCA_80
# sample
# TCGA-3C-AAAU-01 -0.036247  0.027379 -0.015438  0.033716
# TCGA-3C-AALI-01 -0.014227  0.066123 -0.054240 -0.019644
# TCGA-3C-AALJ-01  0.020269 -0.028566  0.031784  0.009290
# TCGA-3C-AALK-01 -0.019704  0.019438 -0.028259  0.002753
# TCGA-4H-AAAK-01 -0.039866  0.051198 -0.021220 -0.026774
# ...                   ...       ...       ...       ...
# TCGA-WT-AB44-01  0.031216 -0.077855 -0.066040 -0.103475
# TCGA-XX-A899-01  0.043574 -0.001265  0.069903 -0.092965
# TCGA-XX-A89A-01 -0.021217 -0.056708  0.004293 -0.080839
# TCGA-Z7-A8R5-01  0.110441 -0.013585  0.106088 -0.035813
# TCGA-Z7-A8R6-01 -0.031392 -0.015380 -0.083493  0.042941
#
# [1229 rows x 4 columns]

# %%
for k in range(2,10):
    kmeans = KMeans(n_clusters=k,n_init=100,max_iter=2000,random_state=123)
    kmeans.fit(clustering_data)
    centroids = kmeans.cluster_centers_
    labels = kmeans.labels_
    sil_score = metrics.silhouette_score(clustering_data, labels)
    ch_score = metrics.calinski_harabasz_score(clustering_data, labels)
    print('k = {}, silhouette width = {}, calinski-harabasz score = {}'.format(k,sil_score,ch_score))
    df_survival['DGCCA_cluster_'+str(k)] = labels
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    

    # The 1st subplot is the silhouette plot, The silhouette coefficient can range from -1, 1 but in this example all lie within [-0.1, 1], /
    # The (n_clusters+1)*10 is for inserting blank space between silhouette plots of individual clusters, to demarcate them clearly.
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(clustering_data) + (k + 1) * 10])



    # Compute the silhouette scores for each sample
    sample_silhouette_values = metrics.silhouette_samples(clustering_data, labels)
    
    y_lower = 10
    color_list = []
    for i in range(k):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / k)
        color_list.append(color)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=sil_score, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
    
    
    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(labels.astype(float) / k)
    ax2.scatter(df_clustering.iloc[:,-2], df_clustering.iloc[:,-1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')
    for i in range(len(centroids)):
        ax2.scatter(centroids[i][0], centroids[i][1], color = color_list[i], edgecolor='black',s = 124, marker='*' )
    #plot.show()

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the PCA_1")
    ax2.set_ylabel("Feature space for the PCA_2")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % k),
                 fontsize=14, fontweight='bold')
# Out:
# k = 2, silhouette width = 0.15251375333360792, calinski-harabasz score = 213.94119340541675
# k = 3, silhouette width = 0.14734207818774203, calinski-harabasz score = 205.19416007230154
# k = 4, silhouette width = 0.15752196735168714, calinski-harabasz score = 201.81110938228167
# k = 5, silhouette width = 0.16039114077967023, calinski-harabasz score = 201.30225455345413
# k = 6, silhouette width = 0.16058080347103373, calinski-harabasz score = 188.8458394919634
# k = 7, silhouette width = 0.15921957263819952, calinski-harabasz score = 179.49949200477826
# k = 8, silhouette width = 0.16102188483475874, calinski-harabasz score = 172.1875819546209
# k = 9, silhouette width = 0.15202300979336245, calinski-harabasz score = 165.2260168356826

# %% [markdown]
# ## KM Plot Generation for each cluster using KaplanMeier Filter

# %%
df_cluster_assignment = df_survival.iloc[:,-10:].reset_index()
df_cluster_assignment.index +=1
df_cluster_assignment.to_csv("cluster_assignment_new.csv")

# %%
kmf = KaplanMeierFitter()

# %%
df_kmf = df_survival.iloc[:,-10:]
df_kmf
# Out:
#                    time  status  DGCCA_cluster_2  DGCCA_cluster_3  \
# sample
# TCGA-3C-AAAU-01  4047.0       0                1                2
# TCGA-3C-AALI-01  4005.0       0                1                2
# TCGA-3C-AALJ-01  1474.0       0                0                1
# TCGA-3C-AALK-01  1448.0       0                1                0
# TCGA-4H-AAAK-01   348.0       0                1                1
# ...                 ...     ...              ...              ...
# TCGA-WT-AB44-01   883.0       0                0                0
# TCGA-XX-A899-01   467.0       0                0                1
# TCGA-XX-A89A-01   488.0       0                1                1
# TCGA-Z7-A8R5-01  3287.0       0                0                2
# TCGA-Z7-A8R6-01  3256.0       0                0                0
#
#                  DGCCA_cluster_4  DGCCA_cluster_5  DGCCA_cluster_6  \
# sample
# TCGA-3C-AAAU-01                0                4                0
# TCGA-3C-AALI-01                0                4                2
# TCGA-3C-AALJ-01                2                1                5
# TCGA-3C-AALK-01                0                4                0
# TCGA-4H-AAAK-01                0                4                2
# ...                          ...              ...              ...
# TCGA-WT-AB44-01                1                3                1
# TCGA-XX-A899-01                3                0                4
# TCGA-XX-A89A-01                1                3                4
# TCGA-Z7-A8R5-01                2                1                5
# TCGA-Z7-A8R6-01                1                2                0
#
#                  DGCCA_cluster_7  DGCCA_cluster_8  DGCCA_cluster_9
# sample
# TCGA-3C-AAAU-01                5                2                8
# TCGA-3C-AALI-01                1                0                4
# TCGA-3C-AALJ-01                0                6                0
# TCGA-3C-AALK-01                5                2                3
# TCGA-4H-AAAK-01                1                0                4
# ...                          ...              ...              ...
# TCGA-WT-AB44-01                6                1                2
# TCGA-XX-A899-01                2                4                5
# TCGA-XX-A89A-01                2                5                7
# TCGA-Z7-A8R5-01                4                4                0
# TCGA-Z7-A8R6-01                3                7                2
#
# [1229 rows x 10 columns]

# %%
T = df_kmf["time"]
E = df_kmf["status"]

# %%
plt.figure(figsize=(20,20))
cluster_number = 2
for k in range(2,10):
    ax = plt.subplot(3, 3, k - 1)
    
    for i in range(k):
        #t = np.linspace(0, 50, 51)
        col_name = 'DGCCA_cluster_'+str(k)
        T = df_kmf[df_kmf[col_name]==i]['time'].to_list()
        E = df_kmf[df_kmf[col_name]==i]['status'].to_list()
        kmf.fit(T, E, label="Cluster_"+str(i))
        ax = kmf.plot_survival_function(ax=ax)
    result = multivariate_logrank_test(df_kmf['time'], df_kmf[col_name], df_kmf['status'])
    #print("##",result.test_statistic)
    print(k,result.p_value)
    #print("IO",result.print_summary())
    plt.title("KM Plot for cluster number ="+str(k)+"\n[pvalue: {}]".format(result.p_value));
# Out:
# 2 0.48805059035681975
# 3 0.13040470920658637
# 4 0.5618145994975869
# 5 0.06257981655925175
# 6 0.05021382635202292
# 7 0.08094516830800191
# 8 0.09727352422297843
# 9 0.05365749922601947
